# %% [markdown]
# # Avacado Project

# %%
#importing all the required libraries for EDA and vizualiztion.
import pandas as pd    # library for EDA.
import numpy as np     # library for numerical calculations.
import seaborn as sns  # library for vizualization.
import matplotlib.pyplot as plt  # library for vizualization.
import math
import warnings
warnings.filterwarnings('ignore')  # to ignore warnings

# %%
#lets load dataset 
df=pd.read_excel(r'C:\Users\Ismail\Desktop\avacado.xlsx')

# %%
#lets check the type of dataset
type(df)
#since our dataset is already dataframe, no need to again make dataframe
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#        Unnamed: 0       Date  AveragePrice  Total Volume     4046       4225  \
# 0               0 2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1 2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2 2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3 2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4 2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...        ...           ...           ...      ...        ...
# 18244           7 2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8 2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9 2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10 2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11 2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %% [markdown]
# # Exploratory Data Analysis(EDA)

# %%
#print columns
df.columns
# Out:
# Index([  'Unnamed: 0',         'Date', 'AveragePrice', 'Total Volume',
#                  4046,           4225,           4770,   'Total Bags',
#          'Small Bags',   'Large Bags',  'XLarge Bags',         'type',
#                'year',       'region'],
#       dtype='object')

# %%
#dropping the unwanted index column
df.drop('Unnamed: 0', axis =1 , inplace =True)

# %%
#print first five rows 
df.head()
# Out:
#         Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0 2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1 2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2 2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3 2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4 2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %%
#checking rows and columns
df.shape
# Out:
# (18249, 13)

# %%
#checking datatype of each column
df.dtypes
# Out:
# Date            datetime64[ns]
# AveragePrice           float64
# Total Volume           float64
# 4046                   float64
# 4225                   float64
# 4770                   float64
# Total Bags             float64
# Small Bags             float64
# Large Bags             float64
# XLarge Bags            float64
# type                    object
# year                     int64
# region                  object
# dtype: object

# %%
#  check null values and summing up columns wise
df.isnull().sum()
# Out:
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
#isnull using heat map
plt.figure(figsize=(12,6))
sns.heatmap(df.isnull())
plt.title('isnull using heatmap', fontsize=15, color='purple')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# ### Observations:

# %% [markdown]
# * from the above outcomes we can see that
#    1. Dataset has 18249 rows and 13 columns, there was 14 columns but we have dropped unwanted index column.
#    2. There are no null values present in the dataset.
#    3. In the heat map there are no lines which shows null, heat map is clean and have no shades..
#    4. Data types of all the columns except Date, Type, year, Region column  are float64 type , where Date column is datetime64[ns] type,  region and type columns are of object type and year is of int64 type.

# %%
#distribution of price
plt.figure(figsize=(12,6))
sns.displot(df['AveragePrice'], kde=True)
plt.show()

# %%
np.sort(df['AveragePrice'])
# Out:
# array([0.44, 0.46, 0.48, ..., 3.12, 3.17, 3.25])

# %% [markdown]
# ### Observation

# %% [markdown]
# The average price of the avacados distributed in the range of  0.44 to 3.25 dollars

# %%
#checking how many types of Avacados are their
df['type'].unique()
# Out:
# array(['conventional', 'organic'], dtype=object)

# %%
types=df.groupby(['type'])['Total Volume'].sum().sort_values(ascending=False).index.values

# total types of Avacados

sns.catplot(kind='bar', data=df, x='type', y='Total Volume',palette='summer',order=types,aspect=2)
plt.title('Types of Avacados', fontsize=14)
plt.xticks(fontsize=12)
plt.xlabel('Types', fontsize=12)
plt.ylabel('Total Volume', fontsize=12)


plt.show()

# %%
df.groupby(['type'])['Total Volume'].sum().sort_values(ascending=False)/1000000
# Out:
# type
# conventional    15087.220911
# organic           436.181682
# Name: Total Volume, dtype: float64

# %% [markdown]
# ### Observations

# %% [markdown]
# * we have two types of Avacados 'conventional' and 'organic'.
# * Highest sold type was 'conventional' type , they were 15087.220911(in millions)
# * Organic was sold only 436.181682(in millions)

# %%
# top 15 regions where Avacados were sold
regions=df.groupby(['region'])['Total Volume'].sum().head(15).sort_values(ascending=False).index.values

plt.figure(figsize=(18,10))
sns.catplot(data=df, x='region',  y='Total Volume',kind='bar', legend_out=False, order = regions, aspect=3.5, palette='rainbow_r')
plt.title('Top 15 regions where Avacados were sold high', fontsize=20)
plt.xlabel('Regions', fontsize=15)
plt.ylabel('Count', fontsize=15)
plt.show()

# %%
len(df['region'].unique())
# Out:
# 54

# %%
(df.groupby(['region'])['Total Volume'].sum().head(15).sort_values(ascending=False))/1000000
# Out:
# region
# California             1028.981653
# DallasFtWorth           208.419287
# Denver                  138.902536
# BaltimoreWashington     134.713919
# Chicago                 133.702339
# Boston                   97.273985
# Atlanta                  88.605119
# Detroit                  63.422419
# CincinnatiDayton         44.522008
# Charlotte                35.555544
# GrandRapids              30.211736
# Columbus                 29.993361
# BuffaloRochester         22.962470
# Albany                   16.067800
# Boise                    14.413188
# Name: Total Volume, dtype: float64

# %% [markdown]
# ### Observations

# %% [markdown]
# * We have 54 diffirent regions where Avacados were sold
# * Highest Avcados were sold  in California compared to other regions they were 1028.9816(in millions)
# * second highest were sold in DallasFtWorth, they were 208.419287(in millions)

# %%
#year of the sales.
print(df['year'].unique())
# Out:
# [2015 2016 2017 2018]

# %%
#Regions where avacados were sold 
plt.figure(figsize=(10,6))
sns.countplot(df['year'], palette='YlGn')
plt.title('Sales per year', fontsize=15)
plt.xlabel('year', fontsize=12)
plt.ylabel('count', fontsize=12)
plt.show()

# %% [markdown]
# ### Observations

# %% [markdown]
# * We have sales from 2015, 2016, 2017, 2018 in the dataset
# * The sales went high in the year 2017 compared to others gets declined in 2018 to around 1800(in millions)

# %%
# Average price per year
plt.figure(figsize=(10,15))

plt.subplot(2,1,1)
sns.barplot(df['year'], df['AveragePrice'], palette='Greys')
plt.title('Average price per year(bar plot)', fontsize=15, color='maroon')
plt.xlabel('year', fontsize=12)
plt.ylabel('Average prie', fontsize=12)

plt.subplot(2,1,2)
sns.lineplot(df['year'], df['AveragePrice'], color='red', linewidth=2)
plt.title('Average price per year(line plot)', fontsize=15, color='maroon')
plt.xlabel('year', fontsize=12)
plt.ylabel('Average price', fontsize=12)

plt.show()

# %% [markdown]
# ### Observations

# %% [markdown]
# As you see can above the Average price of Avacados was highest in 2017 it was 1.51(in dollars), and then decreased to 1.34(in dollars) in 2018, and the lowest price was in 2016 , it was 1.33(in dollars) compared others.

# %%
#LPU code wise avacados sold

df1=df[4046].sum()/1000000
df2=df[4225].sum()/1000000
df3=df[4770].sum()/1000000
PLUs_df=pd.DataFrame({'PLUs':[4046,4225,4770],'Total_sales':[df1,df2,df3]},index=[0,1,2])

plt.figure(figsize=(8,6))
sns.barplot(PLUs_df['PLUs'],PLUs_df['Total_sales'], palette='icefire')
plt.title('Sales According to  PLU code', fontsize=15)
plt.xlabel('PLU code', fontsize=12)
plt.ylabel('count', fontsize=12)
plt.show()

# %%
PLUs_df
# Out:
#    PLUs  Total_sales
# 0  4046  5347.110739
# 1  4225  5386.275718
# 2  4770   416.802342

# %% [markdown]
# ### Observations

# %% [markdown]
# As you can see above that Avacados with PLU code '4225' has the highest sales of 5347.11(in millions) from the year 2015 to 2018 compared to other code types and Avacados with PLUs code '4770' has least sales of 416.80(in millions) from the year 2015 to 2018

# %%
#Avacados sold based on years
df_copy=df.copy()
df_copy.drop(['Date','AveragePrice','Total Volume','region','Total Bags','Small Bags','Large Bags','XLarge Bags'],axis=1,inplace=True)


df_copy.groupby(['year']).sum().plot(kind='bar',figsize=(12,6),legend=True)
plt.legend(fontsize=12)
plt.title ('Avacados sold based on years', fontsize=15)
plt.xlabel('Year',fontsize=14)
plt.ylabel('count', fontsize=14)


plt.show()

# %% [markdown]
# ### Observations

# %% [markdown]
# * from above we can see that in  the years 2015 and 2016  avacados with PLU code '4225' were sold highest.
# * In 2017 and in 2018 avacodos with PLU code '4046' were sold highest in numbers

# %%
#Avacados sold based on bag sixe

df1=df['Small Bags'].sum()/1000000
df2=df['Large Bags'].sum()/1000000
df3=df['XLarge Bags'].sum()/1000000
Bag_size_df=pd.DataFrame({'Bag Size':['Small Bags','Large Bags','XLarge Bags'],'Total_sales':[df1,df2,df3]},index=[0,1,2])

plt.figure(figsize=(6,5))
sns.barplot(Bag_size_df['Bag Size'],Bag_size_df['Total_sales'], palette='PuBu')
plt.title('Avacados sold based on Bag sixe', fontsize=15)
plt.xlabel('Bag Size', fontsize=12)
plt.ylabel('count', fontsize=12)
plt.show()

# %%
Bag_size_df
# Out:
#       Bag Size  Total_sales
# 0   Small Bags  3324.870838
# 1   Large Bags   991.615771
# 2  XLarge Bags    56.689177

# %% [markdown]
# ### Observations

# %% [markdown]
# * From the above we can see that small bags has sold highest in numbers 3324.87(in millions) bags compared to other bags from 2015 to 2018
# * Xlarge bags were the least sold 56.689 (in millions) bags compared to others.

# %%
#Total bags sold according to year
df_copy1=df.copy()
df_copy1.drop(['Date','AveragePrice','Total Volume',4046,4225,4770,'region','Total Bags'],axis=1,inplace=True)
df_copy1.groupby(['year']).sum().plot(kind='bar',figsize=(12,6),legend=True)
plt.legend(fontsize=13)
plt.title ('Total Bags Sold according to year', fontsize=15)
plt.xlabel('year', fontsize=13)
plt.ylabel('Bags count', fontsize=13)
plt.show()

# %% [markdown]
# ### Observations

# %% [markdown]
# * From  the above we can see that in every year from 2015 to 2018 small bags has sold highest in numbers
# * XLarge bags has sold least in numbers.

# %%
#vazualising the whole complete dataset using pair plot.
plt.figure(figsize=(25,25))
sns.pairplot(df)
plt.xticks(size=15)
plt.yticks(size=15)
plt.show()

# %% [markdown]
# pairplot gives the realtionship between all the columns present in the datset.

# %% [markdown]
# # Correlation:

# %%
df.corr()
# Out:
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000     -0.192752 -0.208317 -0.172928 -0.179446
# Total Volume     -0.192752      1.000000  0.977863  0.974181  0.872202
# 4046             -0.208317      0.977863  1.000000  0.926110  0.833389
# 4225             -0.172928      0.974181  0.926110  1.000000  0.887855
# 4770             -0.179446      0.872202  0.833389  0.887855  1.000000
# Total Bags       -0.177088      0.963047  0.920057  0.905787  0.792314
# Small Bags       -0.174730      0.967238  0.925280  0.916031  0.802733
# Large Bags       -0.172940      0.880640  0.838645  0.810015  0.698471
# XLarge Bags      -0.117592      0.747157  0.699377  0.688809  0.679861
# year              0.093197      0.017193  0.003353 -0.009559 -0.036531
#
#               Total Bags  Small Bags  Large Bags  XLarge Bags      year
# AveragePrice   -0.177088   -0.174730   -0.172940    -0.117592  0.093197
# ...

# %%
#df.corr() using heatmap
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(),linewidth='0.5',linecolor='white',annot=True, annot_kws={'size': 12})
plt.title('Correlation between columns', size=28)
plt.xticks(size=14)
plt.yticks(size=14)
plt.show()

# %% [markdown]
# ### Observations

# %% [markdown]
# 1. All the columns except year show negative correaltion with averageprice
# 2. Total Bags and Small Bags have 99 percent  positive correlation, it is highest correaltion in the dataset. It means most of avacados sold are of small bags.
# 3. 4046 and 4225 shows 98 and 97 percent positive corealtion with total volume.
# 4. small bags shows 93 and 92 percent correaltion with small bags respectively , it means avacados in small bags are more of 4046 and 4225 type.

# %% [markdown]
# # Describing Dataset

# %%
df.describe(include='all')
# Out:
#                        Date  AveragePrice  Total Volume          4046  \
# count                 18249  18249.000000  1.824900e+04  1.824900e+04
# unique                  169           NaN           NaN           NaN
# top     2015-12-27 00:00:00           NaN           NaN           NaN
# freq                    108           NaN           NaN           NaN
# first   2015-01-04 00:00:00           NaN           NaN           NaN
# last    2018-03-25 00:00:00           NaN           NaN           NaN
# mean                    NaN      1.405978  8.506440e+05  2.930084e+05
# std                     NaN      0.402677  3.453545e+06  1.264989e+06
# min                     NaN      0.440000  8.456000e+01  0.000000e+00
# 25%                     NaN      1.100000  1.083858e+04  8.540700e+02
# 50%                     NaN      1.370000  1.073768e+05  8.645300e+03
# 75%                     NaN      1.660000  4.329623e+05  1.110202e+05
# ...

# %% [markdown]
# # checking outliers

# %%
#vizualizing outliers
df_1=df.copy()
df_1.drop(['Date','year','type','region',4046,4225,4770], axis=1, inplace=True)

list_col=list(df_1.columns)
df_1.plot(kind='box', title=list_col, subplots=True, layout=(4,4), fontsize=1, figsize=(15,15), color='green')
plt.show()

# %% [markdown]
# ### Observations

# %% [markdown]
# There might be outliers present in all the columns

# %% [markdown]
# # skewness:

# %%
df.skew()
# Out:
# AveragePrice     0.580303
# Total Volume     9.007687
# 4046             8.648220
# 4225             8.942466
# 4770            10.159396
# Total Bags       9.756072
# Small Bags       9.540660
# Large Bags       9.796455
# XLarge Bags     13.139751
# year             0.215339
# dtype: float64

# %%
#vizualizing skewness
df_2=df.copy()
df_2.drop(['Date','year','type','region'], axis=1, inplace=True)
df_2.plot(kind='kde', subplots=True, layout=(5,4),sharex= False, legend= True, fontsize=1, figsize=(15,15))
plt.show()

# %% [markdown]
# ### Observations

# %% [markdown]
# * Every column has skewness
# * Binary heads can be seen in Average price coulmn

# %% [markdown]
# # Findings(insights)

# %% [markdown]
# Fom the above analysis we can conclude that:
# * The most sold bags are small bags which has avacados with 4046 and 4225 PLU code, so small bags with these type were promoted.
# * The most sold type are conventional type so it is produced more.
# * consumers are prefrerring above mentioned avacados more.
# * 2017 was most highest avacados sold year.

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ### Keeping average price as target variable

# %% [markdown]
# # VIF(checking multicolinearity)

# %%
#library for VIF
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
x=df.drop(['AveragePrice','Date','type','year','region'],axis=1)
len(x.columns)
# Out:
# 8

# %%
x.head()
# Out:
#    Total Volume     4046       4225    4770  Total Bags  Small Bags  \
# 0      64236.62  1036.74   54454.85   48.16     8696.87     8603.62
# 1      54876.98   674.28   44638.81   58.33     9505.56     9408.07
# 2     118220.22   794.70  109149.67  130.50     8145.35     8042.21
# 3      78992.15  1132.00   71976.41   72.58     5811.16     5677.40
# 4      51039.60   941.48   43838.39   75.78     6183.95     5986.26
#
#    Large Bags  XLarge Bags
# 0       93.25          0.0
# 1       97.49          0.0
# 2      103.14          0.0
# 3      133.76          0.0
# 4      197.69          0.0

# %%
VIF =[]
for i in range(len(x.columns)):
    VIF.append(variance_inflation_factor(exog=x.values, exog_idx=i))

datavif={'Features':x.columns, 'VIF value': VIF}    
vif_df=pd.DataFrame(datavif)
vif_df
# Out:
#        Features     VIF value
# 0  Total Volume  5.194565e+09
# 1          4046  6.923184e+08
# 2          4225  6.311271e+08
# 3          4770  4.956326e+06
# 4    Total Bags  2.502000e+14
# 5    Small Bags  1.429714e+14
# 6    Large Bags  1.521486e+13
# 7   XLarge Bags  7.853860e+10

# %% [markdown]
# #VIF threshold=10
# * so we dont have any multicolinearity issue with our dataset
# * all the VIF values are under threshold values

# %% [markdown]
# # Feature selection

# %% [markdown]
# *we have observed above that date and year of the are highly correlated and tota volume and total bags are highly correalted and total bags contains small bags , large bags and xl bags so total bags and year column has to be dropped.

# %%
df.drop(['Total Bags', 'year'], axis=1,inplace=True)

# %% [markdown]
# # Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder

#creating instance
le=LabelEncoder()

#training data
le.fit(df['type'])
#transforming data
df['type']=le.transform(df['type'])

le.fit(df['region'])
df['region']=le.transform(df['region'])

le.fit(df['Date'])
df['Date']=le.transform(df['Date'])

# %%
df.sample(5)
# Out:
#        Date  AveragePrice  Total Volume       4046        4225       4770  \
# 7440    134          1.29     104351.36   41263.14    27919.48    1465.50
# 1346      5          1.06    2734006.98  732854.05  1222159.62  159491.59
# 11977    59          1.79       1282.87      23.61      213.64       0.00
# 9429      8          1.55       3520.47      17.44      126.08       0.00
# 4707     76          0.86     682680.66  154975.49   168948.72   19367.47
#
#        Small Bags  Large Bags  XLarge Bags  type  region
# 7440     26704.33     6275.57       723.34     0      34
# 1346    543231.71    75649.40       620.61     0      25
# 11977     1045.62        0.00         0.00     1       0
# 9429      3376.95        0.00         0.00     1       5
# 4707    337166.84     1625.57       596.57     0      36

# %% [markdown]
# # Removing outliers:

# %% [markdown]
# using Zscore technique

# %%
from scipy.stats import zscore

z=np.abs(zscore(df))
z.shape
# Out:
# (18249, 11)

# %%
threshold = 3   # rule of thumb
#index number
print(np.where(z>3))
# Out:
# (array([  346,   359,   780, ..., 17304, 17402, 17428], dtype=int64), array([3, 3, 8, ..., 1, 1, 1], dtype=int64))

# %%
len(np.where(z>3)[0])
# Out:
# 1586

# %% [markdown]
# As we can see above there are 1773 outliers present in th dataset.

# %%
df_new=df[(z<3).all(axis=1)]
print('old dataframe',df.shape)
print('new dataframe',df_new.shape)
print('no of rows dropped',df.shape[0]-df_new.shape[0])
# Out:
# old dataframe (18249, 11)
# new dataframe (17651, 11)
# no of rows dropped 598

# %% [markdown]
# we have dropped the rows which has outliers

# %% [markdown]
# # Splitting data into x(features) and y(target)

# %% [markdown]
# Keeping AveragePrice as Target column

# %%
#splitting data into x and y 
x=df_new.drop('AveragePrice', axis=1) # dropping target column from dataframe and assigning the dataframe as x
y=df_new['AveragePrice'] #assigning target column(W) to y variable

# %%
x.sample() # we can see below that we have only independent data in 'x'
# Out:
#       Date  Total Volume       4046     4225   4770  Small Bags  Large Bags  \
# 1631    32     240185.69  128769.54  46941.6  91.62    45260.21    19122.72
#
#       XLarge Bags  type  region
# 1631          0.0     0      31

# %%
y.sample()
# Out:
# 17816    2.03
# Name: AveragePrice, dtype: float64

# %%
#converting df ino arrays because model takes arrays
x=np.array(x)
y=np.array(y)

# %% [markdown]
# # Removing skewness

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')

# %%
x_df=pd.DataFrame(x)

# %%
x_df.skew()
# Out:
# 0   -0.274852
# 1   -0.008642
# 2   -0.039282
# 3   -0.044675
# 4    0.024168
# 5   -0.024405
# 6   -0.110913
# 7    0.853758
# 8   -0.037741
# 9   -0.257799
# dtype: float64

# %% [markdown]
# # scaling independent data

# %% [markdown]
# using StandardScaler

# %%
#mean=0, std=1
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
scaler.fit(x)
x_scaled=scaler.transform(x)

# %% [markdown]
# # Model Building and Evaluation

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %% [markdown]
# ### Since our target variable(AveragePrice) is continous data we use Regression Models

# %% [markdown]
# # Linear Regression

# %% [markdown]
# ### Finding Best Random State for LinerRegression

# %%
from sklearn.linear_model import LinearRegression

maxAcc=0
maxRS=0
scores=[]

for i in range(1,1500):
    x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.20,random_state=i)
    #creating instance for linearRegression
    lm=LinearRegression()
    #training the Model
    lm.fit(x_train,y_train)
    #predicting  the target test value
    pred_lm=lm.predict(x_test)
    acc=r2_score(y_test,pred_lm)
    
    if acc>maxAcc:
        maxAcc=acc
        maxRS=i
        print('Accuracy', maxAcc, 'random_state', maxRS)
# Out:
# Accuracy 0.5284450174307815 random_state 1
# Accuracy 0.5423085814089526 random_state 3
# Accuracy 0.5518413082239717 random_state 5
# Accuracy 0.5530122273340415 random_state 6
# Accuracy 0.5530514534730331 random_state 483
# Accuracy 0.5542847061928462 random_state 484
# Accuracy 0.5566915140899573 random_state 786
# Accuracy 0.5577639323182886 random_state 833
# Accuracy 0.5581246387238381 random_state 1106

# %% [markdown]
# random state 1106 gives best accuracy of 0.55 compared to others

# %% [markdown]
# ## LinearRegression with best random state

# %%
x_train1,x_test1,y_train1,y_test1=train_test_split(x_scaled,y,test_size=0.20,random_state=1106)

# %%
#printing shape of train and test data
print('x_train1 shape: ',x_train1.shape)
print('x_test1 shape: ',x_test1.shape)
print('y_train1 shape: ',y_train1.shape)
print('y_test1 shape: ',y_test1.shape)
# Out:
# x_train1 shape:  (14120, 10)
# x_test1 shape:  (3531, 10)
# y_train1 shape:  (14120,)
# y_test1 shape:  (3531,)

# %%
#creating instance for linearRegression
lm=LinearRegression()
#training the Model
lm.fit(x_train1,y_train1)
#predicting  the target value
lm_pred=lm.predict(x_test1)

# %% [markdown]
# ## Evaluation

# %%
# calculating the mean absolute error
from sklearn.metrics import mean_absolute_error

abserror=mean_absolute_error(y_test1,lm_pred)

#calculating the percentage of mean absolute rror
mean_abs_percentage_error= 100 * (abserror / y_test1)

print(' mean absolute error:', abserror,'\n','mean absolute error percentage:', round(np.mean(mean_abs_percentage_error),2),'%')
# Out:
#  mean absolute error: 0.2074127875172641
#  mean absolute error percentage: 15.95 %

# %%
#calculating the mean squared log error
from sklearn.metrics import mean_squared_log_error

msle=mean_squared_log_error(y_test1,lm_pred)
print(' mean squared log error:', msle)
# Out:
#  mean squared log error: 0.011837822930661674

# %%
#calculating mean squared error
from sklearn.metrics import mean_squared_error

mse=mean_squared_error(y_test1,lm_pred)

#calculating the percentage of mean squared error
mse_percentage= 100 * (mse / y_test1)

print(' mean squared error:', mse,'\n','mean squared error percentage:', round(np.mean(mse_percentage),2),'%')
# Out:
#  mean squared error: 0.06958322222420268
#  mean squared error percentage: 5.35 %

# %%
#calculating root mean squred error
rmse=np.sqrt(mse)

print('Root mean squared error:',rmse)
# Out:
# Root mean squared error: 0.2637863192514022

# %%
#calculating score of train and test data
print('score for training of model: ',lm.score(x_train1,y_train1))
# Out:
# score for training of model:  0.5260768153364688

# %%
#calculating r2_score
from sklearn.metrics import r2_score

print('r2_score:', r2_score(y_test1,lm_pred),'\n\nAccuracy:',round(100*(r2_score(y_test1,lm_pred)),2),'%')
# Out:
# r2_score: 0.5581246387238381
#
# Accuracy: 55.81 %

# %% [markdown]
# ## cross-validation of the model

# %%
from sklearn.model_selection import cross_val_score

test_score=r2_score(y_test1,lm_pred)

#Linear Regression
scr=cross_val_score(lm,x,y,cv=5)
print('cross validation score of LinearRegression at cross fold 5: ',100*scr.mean(), 'and accuracy score of testing model is:',test_score*100   )
# Out:
# cross validation score of LinearRegression at cross fold 5:  19.17734429179098 and accuracy score of testing model is: 55.81246387238381

# %% [markdown]
# # Random Forest Regressor

# %% [markdown]
# ### Finding Best Random State for Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

maxAcc=0
maxRS=0

for i in range(80,100):
    x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.20,random_state=i)
    #creating instance for RandomForestRegressor
    RFR = RandomForestRegressor(n_estimators = 20, random_state = 50)
    # training model using training data
    RFR.fit(x_train, y_train)
    #predicting the data
    pred_RFR=RFR.predict(x_test)
    acc=r2_score(y_test,pred_RFR)
    
    if acc>maxAcc:
        maxAcc=acc
        maxRS=i
        print('Accuracy', maxAcc, 'random_state', maxRS)
# Out:
# Accuracy 0.8948206316355556 random_state 80
# Accuracy 0.8994886238534069 random_state 81
# Accuracy 0.9048204631004074 random_state 83

# %% [markdown]
# At n_estimators 20 ,Random state of 83 is giving best accuracy of 0.90 compared to other random states

# %% [markdown]
# ## Random Forest Regressor with best random state

# %%
x_train2,x_test2,y_train2,y_test2=train_test_split(x_scaled,y,test_size=0.20,random_state=83)

# %%
#printing shape of train and test data
print('x_train2 shape: ',x_train2.shape)
print('x_test2 shape: ',x_test2.shape)
print('y_train2 shape: ',y_train2.shape)
print('y_test2 shape: ',y_test2.shape)
# Out:
# x_train2 shape:  (14120, 10)
# x_test2 shape:  (3531, 10)
# y_train2 shape:  (14120,)
# y_test2 shape:  (3531,)

# %%
#creating instance for RandomForestRegressor
RFR = RandomForestRegressor(n_estimators = 20, random_state = 50)

# training model using training data
RFR.fit(x_train2, y_train2)

#predicting the data
RFR_pred=RFR.predict(x_test2)

# %% [markdown]
# ## Evaluation

# %%
# calculating the mean absolute error
from sklearn.metrics import mean_absolute_error

abserror=mean_absolute_error(y_test2,RFR_pred)

#calculating the percentage of mean absolute rror
mean_abs_percentage_error= 100 * (abserror / y_test2)

print(' mean absolute error:', abserror,'\n','mean absolute error percentage:', round(np.mean(mean_abs_percentage_error),2),'%')
# Out:
#  mean absolute error: 0.08457887284055507
#  mean absolute error percentage: 6.55 %

# %%
#calculating mean squared error
from sklearn.metrics import mean_squared_error

mse=mean_squared_error(y_test2,RFR_pred)

#calculating the percentage of mean squared error
mse_percentage= 100 * (mse / y_test2)

print(' mean squared error:', mse,'\n','mean squared error percentage:', round(np.mean(mse_percentage),2),'%')
# Out:
#  mean squared error: 0.01403030090625885
#  mean squared error percentage: 1.09 %

# %%
#calculating root mean squred error
rmse=np.sqrt(mse)

print('Root mean squared error:',rmse)
# Out:
# Root mean squared error: 0.11844957115270131

# %%
#calculating the mean squared log error
from sklearn.metrics import mean_squared_log_error

msle=mean_squared_log_error(y_test2,RFR_pred)
print(' mean squared log error:', msle)
# Out:
#  mean squared log error: 0.0023470445530471827

# %%
#calculating score of train and test data
print('score for training of model: ',RFR.score(x_train2,y_train2))
# Out:
# score for training of model:  0.9827236841111839

# %%
#calculating r2_score
from sklearn.metrics import r2_score

print('r2_score:', r2_score(y_test2,RFR_pred),'\n\nAccuracy:',round(100*(r2_score(y_test2,RFR_pred)),2),'%')
# Out:
# r2_score: 0.9048204631004074
#
# Accuracy: 90.48 %

# %% [markdown]
# ## cross-validation of the model

# %%
from sklearn.model_selection import cross_val_score

test_score=r2_score(y_test2,RFR_pred)

#Super Vector Regressor
scr=cross_val_score(RFR,x,y,cv=15)
print('cross validation score of Random Forest Regressor at cross fold 15: ',100*scr.mean(), 'and accuracy score of testing model is:',test_score*100)
# Out:
# cross validation score of Random Forest Regressor at cross fold 15:  52.125513815159884 and accuracy score of testing model is: 90.48204631004074

# %% [markdown]
# # XGBRegressor

# %%
! pip install xgboost==1.0.1
# Out:
# ...
# WARNING: Ignoring invalid distribution -rkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -arkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -arkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -arkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rkupsafe (c:\programdata\anaconda3\lib\site-packages)
# ...

# %%
from xgboost.sklearn import XGBRegressor

# %%
xgb=XGBRegressor()

# %% [markdown]
# ### Finding best random state for XGBRegressor

# %%
maxAcc=0
maxRS=0

for i in range(50,80):
    x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.20,random_state=i)
    #training the data
    xgb.fit(x_train,y_train)

    #predicting the data
    pred_xgb=xgb.predict(x_test)
    acc=r2_score(y_test,pred_xgb)
    
    if acc>maxAcc:
        maxAcc=acc
        maxRS=i
        print('Accuracy', maxAcc, 'random_state', maxRS)
# Out:
# Accuracy 0.9135582102910725 random_state 50
# Accuracy 0.9151738526627516 random_state 53
# Accuracy 0.9154740335153118 random_state 58

# %% [markdown]
# from above we can see that ata random state '58' the model is giving accuracy of 0.91

# %% [markdown]
# ## XGBRegressor with best random state

# %%
x_train4,x_test4,y_train4,y_test4=train_test_split(x_scaled,y,test_size=0.20,random_state=58)

# %%
#printing shape of train and test data
print('x_train4 shape: ',x_train4.shape)
print('x_test4 shape: ',x_test4.shape)
print('y_train4 shape: ',y_train4.shape)
print('y_test4 shape: ',y_test4.shape)
# Out:
# x_train4 shape:  (14120, 10)
# x_test4 shape:  (3531, 10)
# y_train4 shape:  (14120,)
# y_test4 shape:  (3531,)

# %%
#training the data
xgb.fit(x_train4,y_train4)

#predicting the data
xgb_pred=xgb.predict(x_test4)

# %% [markdown]
# ## Evaluation

# %%
# calculating the mean absolute error
from sklearn.metrics import mean_absolute_error

abserror=mean_absolute_error(y_test4,xgb_pred)

#calculating the percentage of mean absolute rror
mean_abs_percentage_error= 100 * (abserror / y_test4)

print(' mean absolute error:', abserror,'\n','mean absolute error percentage:', round(np.mean(mean_abs_percentage_error),2),'%')
# Out:
#  mean absolute error: 0.08374386374722861
#  mean absolute error percentage: 6.44 %

# %%
#calculating mean squared error
from sklearn.metrics import mean_squared_error

mse=mean_squared_error(y_test4,xgb_pred)

#calculating the percentage of mean squared error
mse_percentage= 100 * (mse / y_test4)

print(' mean squared error:', mse,'\n','mean squared error percentage:', round(np.mean(mse_percentage),2),'%')
# Out:
#  mean squared error: 0.012756815002725417
#  mean squared error percentage: 0.98 %

# %%
#calculating root mean squred error
rmse=np.sqrt(mse)

print('Root mean squared error:',rmse)
# Out:
# Root mean squared error: 0.11294607121421009

# %%
#calculating the mean squared log error
from sklearn.metrics import mean_squared_log_error

msle=mean_squared_log_error(y_test4,xgb_pred)
print(' mean squared log error:', msle)
# Out:
#  mean squared log error: 0.0020972046257856005

# %%
#calculating score of train and test data
print('score for training of model: ',xgb.score(x_train4,y_train4))
# Out:
# score for training of model:  0.9649307317837618

# %%
#calculating r2_score
from sklearn.metrics import r2_score

print('r2_score:', r2_score(y_test4,xgb_pred),'\n\nAccuracy:',round(100*(r2_score(y_test4,xgb_pred)),2),'%')
# Out:
# r2_score: 0.9154740335153118
#
# Accuracy: 91.55 %

# %% [markdown]
# ## cross-validation of the model

# %%
from sklearn.model_selection import cross_val_score

test_score=r2_score(y_test4,xgb_pred)

#XGBRegressor
scr=cross_val_score(xgb,x,y,cv=26)
print('cross validation score of XGBRegressor at cross fold 26: ',100*scr.mean(), 'and accuracy score of testing model is:',test_score*100)
# Out:
# cross validation score of XGBRegressor at cross fold 26:  65.0652139611434 and accuracy score of testing model is: 91.54740335153117

# %% [markdown]
# # Regularization

# %%
from sklearn.linear_model import Lasso

# %%
maxAcc=0
maxRS=0
scores=[]

for i in range(1,1500):
    x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.20,random_state=i)
    ls=Lasso()
    ls.fit(x_train,y_train)
    ls_pred=ls.predict(x_test)
    scores.append(r2_score(y_test,ls_pred))
    
print(np.argmax(scores))
# Out:
# 998

# %% [markdown]
# ## Regularization with best random state

# %%
x_train5,x_test5,y_train5,y_test5=train_test_split(x_scaled,y,test_size=0.20,random_state=998)

# %%
#printing shape of train and test data
print('x_train5 shape: ',x_train5.shape)
print('x_test5 shape: ',x_test5.shape)
print('y_train5 shape: ',y_train5.shape)
print('y_test5 shape: ',y_test5.shape)
# Out:
# x_train5 shape:  (14120, 10)
# x_test5 shape:  (3531, 10)
# y_train5 shape:  (14120,)
# y_test5 shape:  (3531,)

# %%
#creating insatnce
ls=Lasso()
#training model
ls.fit(x_train5,y_train5)
#predicting data
ls_pred=ls.predict(x_test5)

# %% [markdown]
# ## Evaluation

# %%
# calculating the mean absolute error
from sklearn.metrics import mean_absolute_error

abserror=mean_absolute_error(y_test5,ls_pred)

#calculating the percentage of mean absolute rror
mean_abs_percentage_error= 100 * (abserror / y_test5)

print(' mean absolute error:', abserror,'\n','mean absolute error percentage:', round(np.mean(mean_abs_percentage_error),2),'%')
# Out:
#  mean absolute error: 0.31358053797887264
#  mean absolute error percentage: 24.32 %

# %%
#calculating mean squared error
from sklearn.metrics import mean_squared_error

mse=mean_squared_error(y_test5,ls_pred)

#calculating the percentage of mean squared error
mse_percentage= 100 * (mse / y_test5)

print(' mean squared error:', mse,'\n','mean squared error percentage:', round(np.mean(mse_percentage),2),'%')
# Out:
#  mean squared error: 0.14768373989335154
#  mean squared error percentage: 11.45 %

# %%
#calculating root mean squred error
rmse=np.sqrt(mse)

print('Root mean squared error:',rmse)
# Out:
# Root mean squared error: 0.3842964219106802

# %%
#calculating the mean squared log error
from sklearn.metrics import mean_squared_log_error

msle=mean_squared_log_error(y_test5,ls_pred)
print(' mean squared log error:', msle)
# Out:
#  mean squared log error: 0.025782098566151712

# %%
#calculating score of train model
print('score for training of model: ',ls.score(x_train5,y_train5))
# Out:
# score for training of model:  0.0

# %%
#calculating r2_score
from sklearn.metrics import r2_score

print('r2_score:', r2_score(y_test5,ls_pred),'\n\nAccuracy:',round(100*(r2_score(y_test5,ls_pred)),2),'%')
# Out:
# r2_score: -0.0007587044904189266
#
# Accuracy: -0.08 %

# %% [markdown]
# ## cross-validation of the model

# %%
from sklearn.model_selection import cross_val_score

test_score=r2_score(y_test5,ls_pred)

#lasso regularization
scr=cross_val_score(ls,x,y,cv=15)
print('cross validation score of lasso at cross fold 4: ',100*scr.mean(), 'and accuracy score of testing model is:',test_score*100)
# Out:
# cross validation score of lasso at cross fold 4:  -114.82042265703802 and accuracy score of testing model is: -0.07587044904189266

# %% [markdown]
# ## Hyper Parameter Tuning: Ensembled techniques

# %% [markdown]
# From the above model XGBregressor working more efficient compared to others so we continue hyper parameter tuning with XGBRegressor

# %%
from sklearn.model_selection import GridSearchCV

# %%
eta=list(np.arange(0.01,0.31,0.01))
parameters={'max_depth':[3,4,5,6,7,8,9,10],'min_child_weight':[1],'subsample':[1],'colsample_bytree':[0.5,1]}

XGB=XGBRegressor()
gcv=GridSearchCV(XGB,parameters)
gcv.fit(x_train4,y_train4)

print(gcv.best_params_)
# Out:
# {'colsample_bytree': 1, 'max_depth': 8, 'min_child_weight': 1, 'subsample': 1}

# %%
XGB_best=XGBRegressor(colsample_bytree=1,max_depth=8,min_child_weight=1,subsample=1,objective='reg:squarederror')
XGB_best.fit(x_train4,y_train4)
XGB_best_pred=XGB_best.predict(x_test4)

XGB_score=r2_score(y_test4,XGB_best_pred)
XGB_best.score(x_train4,y_train4)
XGB_score
# Out:
# 0.921905162193527

# %% [markdown]
# ## Evaluation

# %%
# calculating the mean absolute error
from sklearn.metrics import mean_absolute_error

abserror=mean_absolute_error(y_test4,XGB_best_pred)

#calculating the percentage of mean absolute rror
mean_abs_percentage_error= 100 * (abserror / y_test4)

print(' mean absolute error:', abserror,'\n','mean absolute error percentage:', round(np.mean(mean_abs_percentage_error),2),'%')
# Out:
#  mean absolute error: 0.07836408880336937
#  mean absolute error percentage: 6.03 %

# %%
#calculating mean squared error
from sklearn.metrics import mean_squared_error

mse=mean_squared_error(y_test4,XGB_best_pred)

#calculating the percentage of mean squared error
mse_percentage= 100 * (mse / y_test4)

print(' mean squared error:', mse,'\n','mean squared error percentage:', round(np.mean(mse_percentage),2),'%')
# Out:
#  mean squared error: 0.01178621718268659
#  mean squared error percentage: 0.91 %

# %%
print('score for tarining of model;',XGB_best.score(x_train4,y_train4))
# Out:
# score for tarining of model; 0.989922876777542

# %%
XGB_score=r2_score(y_test4,XGB_best_pred)
XGB_score
# Out:
# 0.921905162193527

# %% [markdown]
# ### cross-validation of the model

# %%
from sklearn.model_selection import cross_val_score

test_score=r2_score(y_test4,XGB_best_pred)

#XGBRegressor
scr=cross_val_score(XGB_best,x,y,cv=25)
print('cross validation score of XGBRegressor at cross fold 25: ',100*scr.mean(), 'and accuracy score of testing model is:',test_score*100)
# Out:
# cross validation score of XGBRegressor at cross fold 25:  62.321709316826016 and accuracy score of testing model is: 92.1905162193527

# %%
plt.figure(figsize=(10,6))
plt.plot(y_test4,label='original')
plt.plot(XGB_best_pred,label='Predicted')
plt.legend()
plt.show()

# %% [markdown]
# # Model Saving(Regression Model)

# %%
import pickle

# %%
XGBR_best_file='Avacados_Regression.pkl'
pickle.dump(XGB_best,open(XGBR_best_file,'wb'))

# %% [markdown]
# # Conclusion:

# %% [markdown]
# * I have selected XGBRegressor as my final model on the basis of its r2_score and cv score are and  respectively.
# * the difference between r2_score and cv score is less among other models , its means the modeel is less underfitting/overfitting.
# * And the root mean squared value for this model is , which is less among others.

# %% [markdown]
# # Classification

# %% [markdown]
# ## Keeping region as target variable

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ## VIF(checking multicolinearity)

# %%
#library for VIF
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
x=df.drop(['Date','type','region'],axis=1)
len(x.columns)
# Out:
# 8

# %%
VIF =[]
for i in range(len(x.columns)):
    VIF.append(variance_inflation_factor(exog=x.values, exog_idx=i))

datavif={'Features':x.columns, 'VIF value': VIF}    
vif_df=pd.DataFrame(datavif)
vif_df
# Out:
#        Features     VIF value
# 0  AveragePrice  1.040754e+00
# 1  Total Volume  5.204428e+09
# 2          4046  6.936333e+08
# 3          4225  6.323251e+08
# 4          4770  4.965743e+06
# 5    Small Bags  2.427236e+08
# 6    Large Bags  2.570059e+07
# 7   XLarge Bags  1.327051e+05

# %% [markdown]
# #VIF threshold=10
# * so we dont have any multicolinearity issue with our dataset
# * all the VIF values are under threshold values

# %% [markdown]
# ## Splitting data into x(features) and y(target)

# %% [markdown]
# Keeping region as Target column

# %%
#splitting data into x and y 
x=df_new.drop('region', axis=1) # dropping target column from dataframe and assigning the dataframe as x
y=df_new['region'] #assigning target column(W) to y variable

# %%
x.sample() # we can see below that we have only independent data in 'x'
# Out:
#       Date  AveragePrice  Total Volume     4046      4225      4770  \
# 6389   125          1.85     165718.77  1824.13  70747.33  36364.98
#
#       Small Bags  Large Bags  XLarge Bags  type
# 6389    41977.67     6300.99      8503.67     0

# %% [markdown]
# ## Removing skewness

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')

# %%
x_df=pd.DataFrame(x)

# %%
x_df.skew()
# Out:
# 0   -0.274852
# 1    0.000464
# 2   -0.008642
# 3   -0.039282
# 4   -0.044675
# 5    0.024168
# 6   -0.024405
# 7   -0.110913
# 8    0.853758
# 9   -0.037741
# dtype: float64

# %% [markdown]
# ## scaling independent data

# %% [markdown]
# using StandardScaler

# %%
#mean=0, std=1
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
scaler.fit(x)
x_scaled=scaler.transform(x)

# %% [markdown]
# ## Model Building and Evaluation

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %% [markdown]
# # Decision Tree Classifier

# %% [markdown]
# ### Finding Best Random State

# %%
from sklearn.tree import DecisionTreeClassifier
maxAcc=0
maxRS=0

for i in range(1,150):
    x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.20,random_state=i)
    DTC=DecisionTreeClassifier() #creating instance 
    DTC.fit(x_train,y_train)  #traing data
    DTC_pred=DTC.predict(x_test) #predicting data.fit(x_train,y_train)
    acc=accuracy_score(y_test,DTC_pred)
    
    if acc>maxAcc:
        maxAcc=acc
        maxRS=i
        print('Accuracy', maxAcc, 'random_state', maxRS)
# Out:
# Accuracy 0.805154347210422 random_state 1
# Accuracy 0.8142169357122628 random_state 4
# Accuracy 0.8156329651656754 random_state 6
# Accuracy 0.8232795242141037 random_state 18

# %%
from the above we can see that the best random state is 18

# %% [markdown]
# ### Decision Tree Classifier with best random state

# %%
#creating train , test split
x_train2,x_test2,y_train2,y_test2=train_test_split(x_scaled,y,test_size=0.20,random_state=18)

DTC=DecisionTreeClassifier() #creating instance 
DTC.fit(x_train2,y_train2)  #traing data
DTC_pred=DTC.predict(x_test2) #predicting data

# %% [markdown]
# ### Evaluation

# %%
#checking score for training model
print('Score for training model :',DTC.score(x_train2,y_train2))
# Out:
# Score for training model : 1.0

# %%
#checking accuracy score
print('Accuracy: ',accuracy_score(y_test2,DTC_pred))
#print confusion matrics
print(confusion_matrix(y_test2,DTC_pred))
#printing classification report
print(classification_report(y_test2,DTC_pred))
# Out:
# Accuracy:  0.8198810535259133
# [[52  0  0 ...  0  0  0]
#  [ 0 62  0 ...  0  0  2]
#  [ 0  0 66 ...  0  0  3]
#  ...
#  [ 0  0  0 ... 37  0  0]
#  [ 0  0  0 ...  0 41  0]
#  [ 0  2  2 ...  0  0 44]]
#               precision    recall  f1-score   support
#
#            0       0.84      0.79      0.81        66
#            1       0.83      0.81      0.82        77
#            2       0.88      0.88      0.88        75
#            3       0.70      0.73      0.72        59
#            4       0.88      0.91      0.90        58
#            5       0.79      0.82      0.80        67
#            6       0.97      0.95      0.96        61
#            7       0.90      0.90      0.90        72
#            8       0.91      0.93      0.92        46
#            9       0.83      0.78      0.81        77
#           10       0.73      0.69      0.71        62
#           11       0.91      0.83      0.87        72
#           12       0.88      0.88      0.88        76
# ...

# %% [markdown]
# ## cross validation

# %%
scr=cross_val_score(DTC,x,y,cv=50)
print('cross validation score of DecissionTreeClassifier at cv folds is : ',scr.mean())
# Out:
# cross validation score of DecissionTreeClassifier at cv folds is :  0.7548022598870057

# %% [markdown]
# # Gaussian Naive Bayes

# %% [markdown]
# ### Finding Best Random State

# %%
from sklearn.naive_bayes import GaussianNB
maxAcc=0
maxRS=0

for i in range(1,1500):
    x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.20,random_state=i)
    GNB = GaussianNB()
    GNB.fit(x_train, y_train)
    GNB_pred=GNB.predict(x_test)
    acc=accuracy_score(y_test,GNB_pred)
    
    if acc>maxAcc:
        maxAcc=acc
        maxRS=i
        print('Accuracy', maxAcc, 'random_state', maxRS)
# Out:
# Accuracy 0.06457094307561598 random_state 1
# Accuracy 0.07703200226564713 random_state 4
# Accuracy 0.0778816199376947 random_state 16
# Accuracy 0.07958085528178986 random_state 637
# Accuracy 0.08043047295383744 random_state 759
# Accuracy 0.08156329651656755 random_state 905

# %% [markdown]
# ### Gaussian Naive Bayes with best random state

# %%
#creating train , test split
x_train4,x_test4,y_train4,y_test4=train_test_split(x_scaled,y,test_size=0.20,random_state=201)

#creating instance
GNB = GaussianNB()

#training data
GNB.fit(x_train4, y_train4)

#predicting data
GNB_pred=GNB.predict(x_test4)

# %% [markdown]
# ## Evaluation

# %%
#checking score for training model
print('Score for training model :',GNB.score(x_train4,y_train4))
# Out:
# Score for training model : 0.06508498583569405

# %%
#checking accuracy score
print('Accuracy: ',accuracy_score(y_test4,GNB_pred))
#print confusion matrics
print(confusion_matrix(y_test4,GNB_pred))
#printing classification report
print(classification_report(y_test4,GNB_pred))
# Out:
# Accuracy:  0.06343811951288587
# [[12  0  0 ...  0  0  0]
#  [ 2  0  0 ...  0 11  0]
#  [ 7  0  0 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 38  0  0]
#  [ 0  0  0 ...  0  7  0]
#  [ 6  0  0 ...  0 29  0]]
#               precision    recall  f1-score   support
#
#            0       0.03      0.18      0.06        65
#            1       0.00      0.00      0.00        69
#            2       0.00      0.00      0.00        60
#            3       0.19      0.10      0.13        60
#            4       0.00      0.00      0.00        63
#            5       0.00      0.00      0.00        69
#            6       0.00      0.00      0.00        52
#            7       0.02      0.02      0.02        62
#            8       0.00      0.00      0.00        63
#            9       0.15      0.23      0.18        66
#           10       0.00      0.00      0.00        68
#           11       0.00      0.00      0.00        67
#           12       0.01      0.03      0.02        59
# ...

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
maxAcc=0
maxRS=0

for i in range(50,80):
    x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.20,random_state=i)
    RFC=RandomForestClassifier() #creating instance 
    RFC.fit(x_train,y_train)  #traing data
    RFC_pred=RFC.predict(x_test) #predicting data
    acc=accuracy_score(y_test,RFC_pred)
    
    if acc>maxAcc:
        maxAcc=acc
        maxRS=i
        print('Accuracy', maxAcc, 'random_state', maxRS)
# Out:
# Accuracy 0.9198527329368451 random_state 50
# Accuracy 0.9215519682809402 random_state 60
# Accuracy 0.924667233078448 random_state 72

# %% [markdown]
# the best random state is 72 which is giving 0.92 accuracy

# %% [markdown]
# ## Random Forest Classifier with best random state

# %%
#creating train , test split
x_train5,x_test5,y_train5,y_test5=train_test_split(x_scaled,y,test_size=0.20,random_state=72)

RFC=RandomForestClassifier() #creating instance 
RFC.fit(x_train5,y_train5)  #traing data
RFC_pred=RFC.predict(x_test5) #predicting data

# %% [markdown]
# ### Evaluation

# %%
#checking score for training model
print('Score for training model :',RFC.score(x_train5,y_train5))
# Out:
# Score for training model : 1.0

# %%
#checking accuracy score
print('Accuracy: ',accuracy_score(y_test5,RFC_pred))
#print confusion matrics
print(confusion_matrix(y_test5,RFC_pred))
#printing classification report
print(classification_report(y_test5,RFC_pred))
# Out:
# Accuracy:  0.9224015859529878
# [[48  0  0 ...  0  0  0]
#  [ 0 60  0 ...  0  0  2]
#  [ 0  0 60 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 37  0  0]
#  [ 0  0  0 ...  1 58  0]
#  [ 0  0  0 ...  0  0 49]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.86      0.87        56
#            1       0.86      0.86      0.86        70
#            2       0.95      1.00      0.98        60
#            3       0.90      0.90      0.90        72
#            4       0.95      0.99      0.97        75
#            5       0.94      0.85      0.89        72
#            6       0.98      1.00      0.99        46
#            7       0.95      0.94      0.94        81
#            8       0.98      1.00      0.99        64
#            9       0.87      0.92      0.89        64
#           10       0.91      0.84      0.87        70
#           11       0.93      0.97      0.95        70
#           12       0.93      0.97      0.95        69
# ...

# %% [markdown]
# ### cross validation¶

# %%
scr=cross_val_score(RFC,x,y,cv=15)
print('cross validation score of RandomForestClassifier at cv folds 15 : ',scr.mean())
# Out:
# cross validation score of RandomForestClassifier at cv folds 15 :  0.8167746509535564

# %% [markdown]
# ## Hyper parameter tuning

# %% [markdown]
# From the above cv scores we can see that RandomForestClassifier is giving highest cv score, so we do Hyperparameter tuning to RandomForestClassifier

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters={'max_features':['auto', 'sqrt'], 'max_depth':['None',4,5,6,7,8], 'criterion':['gini', 'entropy']}

# %%
GCV=GridSearchCV(RandomForestClassifier(),parameters)

# %%
GCV.fit(x_train5, y_train5) #fitting the data into model
# Out:
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': ['None', 4, 5, 6, 7, 8],
#                          'max_features': ['auto', 'sqrt']})

# %%
GCV.best_params_
# Out:
# {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'sqrt'}

# %%
GCV.best_estimator_
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=8)

# %%
RFC_best=RandomForestClassifier(criterion='entropy',max_depth=8,max_features='sqrt',random_state=45) #creating instance 
RFC_best.fit(x_train5,y_train5)  #traing data
RFC_best_pred=RFC.predict(x_test5) #predicting data

# %% [markdown]
# ### Evaluation

# %%
#checking score for training model
print('Score for training model :',RFC_best.score(x_train5,y_train5))
# Out:
# Score for training model : 0.8465297450424929

# %%
#checking accuracy score
print('Accuracy: ',accuracy_score(y_test5,RFC_best_pred))
#print confusion matrics
print(confusion_matrix(y_test5,RFC_best_pred))
#printing classification report
print(classification_report(y_test5,RFC_best_pred))
# Out:
# Accuracy:  0.9224015859529878
# [[48  0  0 ...  0  0  0]
#  [ 0 60  0 ...  0  0  2]
#  [ 0  0 60 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 37  0  0]
#  [ 0  0  0 ...  1 58  0]
#  [ 0  0  0 ...  0  0 49]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.86      0.87        56
#            1       0.86      0.86      0.86        70
#            2       0.95      1.00      0.98        60
#            3       0.90      0.90      0.90        72
#            4       0.95      0.99      0.97        75
#            5       0.94      0.85      0.89        72
#            6       0.98      1.00      0.99        46
#            7       0.95      0.94      0.94        81
#            8       0.98      1.00      0.99        64
#            9       0.87      0.92      0.89        64
#           10       0.91      0.84      0.87        70
#           11       0.93      0.97      0.95        70
#           12       0.93      0.97      0.95        69
# ...

# %% [markdown]
# ## Model Saving(Classificaton)

# %%
import pickle

# %%
RFC_best_file='Avacados_Classification.pkl'
pickle.dump(XGB_best,open(RFC_best_file,'wb'))

# %% [markdown]
# # Conclusion:

# %% [markdown]
# * I have selected RandomForestRegressor as my best model among others on  the basis of its accuracy score which is 0.92, f1-score
# * The difference betweencv score and accuracy score is less which means the model is less underfitting/overfitting
