# %% [markdown]
# # Abalone Case Study

# %%
#importing all the required libraries for EDA and vizualiztion.
import pandas as pd    # library for EDA.
import numpy as np     # library for numerical calculations.
import seaborn as sns  # library for vizualization.
import matplotlib.pyplot as plt  # library for vizualization.
import warnings
warnings.filterwarnings('ignore')  # to ignore warnings

# %%
#loading the data set
df = pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset1/master/abalone.csv')

# %%
#lets check the type of dataset
type(df)
#since our dataset is already dataframe, no need to again make dataframe
# Out:
# pandas.core.frame.DataFrame

# %%
#printing dataframe
df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %% [markdown]
# # EDA

# %%
#print columns
df.columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'Rings'],
#       dtype='object')

# %%
#print first five rows 
df.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
#checking rows and columns
df.shape
# Out:
# (4177, 9)

# %%
#  check null values and summing up columns wise
df.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
#isnull using heat map
plt.rcParams['figure.facecolor']='pink'
plt.figure(figsize=(12,6))
sns.heatmap(df.isnull())
plt.title('isnull using heat map')
plt.show()

# %%
#checking datatype of each column
df.dtypes
# Out:
# Sex                object
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# Rings               int64
# dtype: object

# %% [markdown]
# #observations:
# from the above outcomes we can see that
#    1. Dataframe has 4177 rows and 9 columns.
#    2. There are no null values in the dataframe
#    3. In the heat map there are no lines which shows null, heat map is clean and have no shades..
#    4. Data types of all the columns except sex column and rings column are float64 type , sex column is object tyoe and rings column is int64.

# %%
#lets plot count plot for sex to know how may rows belongs to which sex type.
sns.countplot(df['Sex'])
plt.title('sex count plot')
plt.show()

# %% [markdown]
# Around 1550 rows belongs to male sex type and 1250 rows belongs to female sex type and around 1300 rows belongs to infant sex type.

# %%
#plotting histogram to see vizual insights
df.hist(figsize=(15,10))
plt.show()

# %%
#relationship between length ,diameter and height.
plt.rcParams['figure.figsize']=(15,10)

plt.subplot(2, 2, 1) # row 2, col 2 index 1
sns.scatterplot(x='Length', y='Diameter', data =df, hue='Sex',s=40, cmap=plt.cm.RdYlBu)
plt.title('Length v/s Diameter')

plt.subplot(2, 2, 2) # row 2, col 2 index 2
sns.scatterplot(x='Diameter', y='Height', data =df,hue='Sex' ,s=40, cmap=plt.cm.RdYlBu)
plt.title('Diameter v/s Height')

plt.subplot(2,2, 3) # row 2, col 2 index 3
sns.scatterplot(x='Height', y='Length', data =df, hue='Sex',s=40 ,cmap=plt.cm.RdYlBu)
plt.title('Height v/s Length')

plt.show()

# %%
#realtionship bewteen length and rings
plt.figure(figsize=(15,10))

plt.subplot(2, 1, 1) # row 2, col 2 index 1
sns.barplot(x='Length', y='Rings',data=df)
plt.title('Length v/s Rings')

plt.subplot(2, 1, 2) # row 2, col 2 index 2
sns.scatterplot(x='Length', y='Rings', data =df, hue='Sex' ,s=40)
plt.title('Length v/s Rings')


plt.show()

# %% [markdown]
# From above outcome you can see that rings are increasing in number when length of the abalone is increasing, they are directly proportional to each other.

# %%
#realtionship bewteen Diameter and rings
plt.figure(figsize=(15,10))

plt.subplot(2, 1, 1) # row 2, col 2 index 1
sns.barplot(x='Diameter', y='Rings',data=df)
plt.title('Diameter v/s Rings')

plt.subplot(2, 1, 2) # row 2, col 2 index 2
sns.scatterplot(x='Diameter', y='Rings', data =df, hue='Sex' ,s=40)
plt.title('Diameter v/s Rings')


plt.show()

# %% [markdown]
# From the above outcome you can see that rings are increasing in number when Diameter of the abalone is increasing, they are directly proportional to each other.

# %%
#realtionship bewteen Height and rings
plt.figure(figsize=(15,10))

plt.subplot(2, 1, 1) # row 2, col 2 index 1
sns.barplot(x='Height', y='Rings',data=df)
plt.title('Height v/s Rings')

plt.subplot(2, 1, 2) # row 2, col 2 index 2
sns.scatterplot(x='Height', y='Rings', data =df, hue='Sex' ,s=40)
plt.title('Height v/s Rings')


plt.show()

# %% [markdown]
# From the above outcome you can see that rings are increasing in number when Height of the abalone is increasing, they are directly proportional to each other.

# %%
#vazualising the whole complete dataset using pair plot.
plt.figure(figsize=(25,15))
sns.pairplot(df, hue='Sex')
plt.xticks(size=12)
plt.yticks(size=12)
plt.show()

# %% [markdown]
# From the above pairplot we can see that Rings are increasing in number when are the features are increasing , so all the features are directly prportional to Rings.

# %% [markdown]
# # correlation:

# %%
df.corr()
# Out:
#                   Length  Diameter    Height  Whole weight  Shucked weight  \
# Length          1.000000  0.986812  0.827554      0.925261        0.897914
# Diameter        0.986812  1.000000  0.833684      0.925452        0.893162
# Height          0.827554  0.833684  1.000000      0.819221        0.774972
# Whole weight    0.925261  0.925452  0.819221      1.000000        0.969405
# Shucked weight  0.897914  0.893162  0.774972      0.969405        1.000000
# Viscera weight  0.903018  0.899724  0.798319      0.966375        0.931961
# Shell weight    0.897706  0.905330  0.817338      0.955355        0.882617
# Rings           0.556720  0.574660  0.557467      0.540390        0.420884
#
#                 Viscera weight  Shell weight     Rings
# Length                0.903018      0.897706  0.556720
# Diameter              0.899724      0.905330  0.574660
# Height                0.798319      0.817338  0.557467
# Whole weight          0.966375      0.955355  0.540390
# ...

# %%
#df.corr() using heatmap
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(),linewidth='1.5',linecolor='black',annot=True, annot_kws={'size': 15})
plt.title('Correlation between columns', size=28)
plt.xticks(size=14)
plt.yticks(size=14)
plt.show()

# %% [markdown]
# #observations from df.corr() heatmap
# 1. All the features are positively correlated with Rings.
# 2. Lenght feature have 56 percent of positive correlation with Rings(target column).
# 3. Diameter feature have 57 percent of positive correlation with Rings which is a good correlation.
# 4. Height feature have 56 percent of positive correlation with Rings which is a good correlation.
# 5. Whole weight have 54 percent of positive correlation wit Rings which is also a good correlation.
# 6. Shucked weight have 42 percent of positive correlation with Rings which is also a good correlation.
# 7. Viscera weight have 50 percent of positive correaltion with Rings.
# 8. Shell weight have 63 percent of positive correlation with Rings which is the highest correlation with Rings compared to others

# %% [markdown]
# # Describing Dataset

# %%
df.describe(include='all')
# Out:
#          Sex       Length     Diameter       Height  Whole weight  \
# count   4177  4177.000000  4177.000000  4177.000000   4177.000000
# unique     3          NaN          NaN          NaN           NaN
# top        M          NaN          NaN          NaN           NaN
# freq    1528          NaN          NaN          NaN           NaN
# mean     NaN     0.523992     0.407881     0.139516      0.828742
# std      NaN     0.120093     0.099240     0.041827      0.490389
# min      NaN     0.075000     0.055000     0.000000      0.002000
# 25%      NaN     0.450000     0.350000     0.115000      0.441500
# 50%      NaN     0.545000     0.425000     0.140000      0.799500
# 75%      NaN     0.615000     0.480000     0.165000      1.153000
# max      NaN     0.815000     0.650000     1.130000      2.825500
#
#         Shucked weight  Viscera weight  Shell weight        Rings
# count      4177.000000     4177.000000   4177.000000  4177.000000
# ...

# %% [markdown]
# # checking outliers

# %%
#vizualizing outliers
list_col=list(df.columns[1::1])
df.plot(kind='box', title=list_col, subplots=True, layout=(3,4), legend= True, fontsize=1, figsize=(15,10))
plt.show()

# %% [markdown]
# from above outcome we can say that their might be outliers in all columns.

# %% [markdown]
# # skewness:

# %%
df.skew()
# Out:
# Length           -0.639873
# Diameter         -0.609198
# Height            3.128817
# Whole weight      0.530959
# Shucked weight    0.719098
# Viscera weight    0.591852
# Shell weight      0.620927
# Rings             1.114102
# dtype: float64

# %%
#vizualizing skewness
df.plot(kind='kde', subplots=True, layout=(4,2), sharex= False, legend= True, fontsize=1, figsize=(15,10))
plt.show()

# %% [markdown]
# their is skewness in every column except Rings

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# # Label encoding

# %%
df['Sex'].dtypes
# Out:
# dtype('O')

# %% [markdown]
# as wee can see that Sex columns is object type so we have to do label encoding to covert them into integer type

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
le.fit(df['Sex'])
# Out:
# LabelEncoder()

# %%
le.classes_
# Out:
# array(['F', 'I', 'M'], dtype=object)

# %%
df['Sex']=le.transform(df['Sex'])

# %%
df['Sex'].dtypes
# Out:
# dtype('int32')

# %%
df['Sex']
# Out:
# 0       2
# 1       2
# 2       0
# 3       2
# 4       1
#        ..
# 4172    0
# 4173    2
# 4174    2
# 4175    0
# 4176    2
# Name: Sex, Length: 4177, dtype: int32

# %% [markdown]
# male is 2, female is 0 and infant is 1

# %%
#splitting data into x and y 
x=df.drop('Rings', axis=1)
y=df['Rings']

# %%
x.sample()
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 3237    2   0.635      0.51   0.155         1.156           0.428
#
#       Viscera weight  Shell weight
# 3237           0.289         0.315

# %%
y.sample()
# Out:
# 2403    10
# Name: Rings, dtype: int64

# %%
x=np.array(x)
y=np.array(y)

# %% [markdown]
# # removing skewness

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')

# %%
#checking skewness after removing skewness
pd.DataFrame(x).skew()
# Out:
# 0   -0.176442
# 1   -0.066669
# 2   -0.065977
# 3   -0.115483
# 4   -0.003980
# 5    0.027351
# 6    0.039780
# 7    0.023390
# dtype: float64

# %% [markdown]
# # scaling independent data

# %% [markdown]
# using StandardScaler

# %%
#mean=0, std=1
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
x_scaled=scaler.fit_transform(x)

# %% [markdown]
# # splitting data into train and test

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.2,random_state=422)

# %%
#checking the shape
x_train.shape, y_train.shape, x_test.shape , y_test.shape
# Out:
# ((3341, 8), (3341,), (836, 8), (836,))

# %% [markdown]
# # Model building and Evaluating

# %% [markdown]
# # Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

#creating instance for RandomForestRegressor
RFR = RandomForestRegressor(n_estimators = 200, random_state = 42)

# training model using training data
RFR.fit(x_train, y_train)

#predicting the data
RFR_pred=RFR.predict(x_test)

# %%
# calculating the mean absolute error
abserror= abs(RFR_pred - y_test)
print('mean absolute error:', np.mean(abserror))
# Out:
# mean absolute error: 1.4965011961722492

# %%
#calculating the percentage of mean absolute rror
mean_abs_percentage_error= 100 * (abserror / y_test)
print('mean absolute percentage error:', round(np.mean(mean_abs_percentage_error),2),'%')
# Out:
# mean absolute percentage error: 15.16 %

# %%
#calculation of accuracy of model
accuracy = 100 - np.mean(mean_abs_percentage_error)
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Accuracy: 84.84 %.

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression

#creating instance for linearRegression
lm=LinearRegression()

#training the Model
lm.fit(x_train,y_train)


#predicting  the target value
lm_pred=lm.predict(x_test)

# %%
# calculating the mean absolute error
abserror= abs(lm_pred - y_test)
print('mean absolute error:', np.mean(abserror))
# Out:
# mean absolute error: 1.567434597897473

# %%
#calculating the percentage of mean absolute rror
mean_abs_percentage_error= 100 * (abserror / y_test)
print('mean absolute percentage error:', round(np.mean(mean_abs_percentage_error),2),'%')
# Out:
# mean absolute percentage error: 16.27 %

# %%
#calculation of accuracy of model
accuracy = 100 - np.mean(mean_abs_percentage_error)
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Accuracy: 83.73 %.

# %% [markdown]
# # Super Vector Regressor

# %%
from sklearn.svm import SVR

# %%
#creating the instance
svr=SVR(kernel='rbf')

#training the data
svr.fit(x_train,y_train)

#predicting the data
svr_pred=svr.predict(x_test)

# %%
# calculating the mean absolute error
abserror= abs(svr_pred - y_test)
print('mean absolute error:', np.mean(abserror))
# Out:
# mean absolute error: 1.429963438807357

# %%
#calculating the percentage of mean absolute rror
mean_abs_percentage_error= 100 * (abserror / y_test)
print('mean absolute percentage error:', round(np.mean(mean_abs_percentage_error),2),'%')
# Out:
# mean absolute percentage error: 13.99 %

# %%
#calculation of accuracy of model
accuracy = 100 - np.mean(mean_abs_percentage_error)
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Accuracy: 86.01 %.

# %% [markdown]
# # KNeighbors Regressor

# %%
from sklearn.neighbors import KNeighborsRegressor

#creating the instance
kn = KNeighborsRegressor(n_neighbors=5)

#training the data
kn.fit(x_train,y_train)

#predicting the data
kn_pred=kn.predict(x_test)

# %%
# calculating the mean absolute error
abserror= abs(kn_pred - y_test)
print('mean absolute error:', np.mean(abserror))
# Out:
# mean absolute error: 1.613157894736842

# %%
#calculating the percentage of mean absolute rror
mean_abs_percentage_error= 100 * (abserror / y_test)
print('mean absolute percentage error:', round(np.mean(mean_abs_percentage_error),2),'%')
# Out:
# mean absolute percentage error: 16.04 %

# %%
#calculation of accuracy of model
accuracy = 100 - np.mean(mean_abs_percentage_error)
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Accuracy: 83.96 %.

# %% [markdown]
# # cross validation

# %% [markdown]
# cross validating for all the models builded above to check overfitting if exist.

# %%
from sklearn.model_selection import cross_val_score

# %%
#Random Forest Classifier
scr=cross_val_score(RFR,x,y,cv=10)
print('cross validation score of RandomForestClassifier: ',scr.mean())
# Out:
# cross validation score of RandomForestClassifier:  0.400683911023587

# %%
#Linear Regression
scr=cross_val_score(lm,x,y,cv=10)
print('cross validation score of LinearRegression : ',scr.mean())
# Out:
# cross validation score of LinearRegression :  0.3781542311892211

# %%
#SuperVectorRegressor
scr=cross_val_score(svr,x,y,cv=10)
print('cross validation score of SuperVectorRegressor : ',scr.mean())
# Out:
# cross validation score of SuperVectorRegressor :  0.47445354807778023

# %%
#KNeighborRegressor
scr=cross_val_score(kn,x,y,cv=10)
print('cross validation score of KNeighborRegressor : ',scr.mean())
# Out:
# cross validation score of KNeighborRegressor :  0.36097045518431187

# %% [markdown]
# from the above models SuperVectorRegressor is performing better so we continue with it further.

# %% [markdown]
# # Regularization

# %%
SVR()
# Out:
# SVR()

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso
from sklearn.metrics import r2_score

# %%
parameters={'alpha':[.0001,.001,.01,.1,1,10],'random_state':list(range(0,10))}

ls=Lasso()
gcv=GridSearchCV(ls,parameters)
gcv.fit(x_train,y_train)

print(gcv.best_params_)
# Out:
# {'alpha': 0.001, 'random_state': 0}

# %%
ls_best=Lasso(alpha=0.001,random_state=0)
ls_best.fit(x_train,y_train)
ls_best.score(x_train,y_train)

ls_pred=ls_best.predict(x_test)

ls_score=r2_score(y_test,ls_pred)
ls_score
# Out:
# 0.5391109035412458

# %% [markdown]
# # Model saving

# %%
import pickle

# %%
ls_best_file='Abalone.pkl'
pickle.dump(ls_best,open(ls_best_file,'wb'))
