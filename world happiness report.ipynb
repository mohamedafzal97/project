# %% [markdown]
# # World Happiness Report

# %%
import pandas as pd   #library for data analysis and manipulation.
import numpy as np    #library for numerical calculations.
import warnings
warnings.filterwarnings('ignore')  # to ignore warnings

# %%
#loading dataset
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/DSData/master/happiness_score_dataset.csv')

# %%
#checking the type of dataset
type(df)
#since the dataset is already dataframe so, no need to again create dataframe.
# Out:
# pandas.core.frame.DataFrame

# %%
#printing dataframe
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
#printing columns of dataframe
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
#checking if there are any null values in dataframe and summing up column wise.
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# #observations
# 1. dataframe has 158 rows and 12 columns.
# 2. dataframe does not have null values.

# %% [markdown]
# # Exploratory Data Analysis(EDA)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['figure.facecolor']= 'pink'

# %%
#lets plot scatter plot to see the distribution of data b/w two columns
plt.rcParams['figure.figsize']=(15,7)
sns.scatterplot(x='Economy (GDP per Capita)',y='Happiness Score',data=df,markers=True,hue='Region',s=200)

plt.title('Plot b/w happiness score and Economy (GDP per Capita)',fontsize=15)
plt.legend(loc='best',fontsize=12)
plt.show()

# %% [markdown]
# In the above outcome we can see that western Europe countries are the happiest countries compared to others with happiness score from 6.5 to 7 and above,they the highest GDP compared to others.Sub sharan africa countries are less happiest countries with happiness score range from 3.5 to 5 and they have low GDP compared to others.

# %%
#Plot b/w happiness score and Family
sns.scatterplot(x='Family',y='Happiness Score',data=df,markers=True,hue='Region',s=200)
plt.title('Plot b/w happiness score and Family',fontsize=15)
plt.show()

# %% [markdown]
# in the above we can see that western europe are the happiest with happiness score 6.5 to 7 and above

# %%
#Plot b/w happiness score and Health (Life Expectancy)
sns.scatterplot(x='Health (Life Expectancy)',y='Happiness Score',data=df,markers=True, hue='Region', s=200)
plt.title('Plot b/w happiness score and Health (Life Expectancy)',fontsize=15)
plt.show()

# %% [markdown]
# sub sharan africa countries are less healthy compared to others with health(life expectancy) range of 4.5 and below and western europe are healthier compared to others with health(life expectancy) range of 0.85 to 1.

# %%
#Plot b/w happiness score and Freedom
sns.scatterplot(x='Freedom',y='Happiness Score',data=df,markers=True, hue='Region', s=200)
plt.title('Plot b/w happiness score and Freedom',fontsize=15)
plt.show()

# %% [markdown]
# In the above outcome we can see that Western Europe has more freedom with range 0.65 to 0.7 and they are the happiest.Sub sharan africa countries are again less happy compared to others with happiness score below 5.

# %%
#Plot b/w happiness score and Trust (Government Corruption)
sns.scatterplot(x='Trust (Government Corruption)',y='Happiness Score',data=df,markers=True,hue='Region',s=200)
plt.title('Plot b/w happiness score and Trust (Government Corruption)',fontsize=15)
plt.show()

# %% [markdown]
# Most of the Sub Saharan contries are less corrupted and less happy. Western Europe are the highly corrupted countries compared to others and they are  the happiest. Apart from this other countries are moderately corrupted and moderately happy with happiness score ranges from 4.5 to 6.5

# %%
#Plot b/w happiness score and Generosity
sns.scatterplot(x='Generosity',y='Happiness Score',data=df,markers=True,hue='Region',s=200)
plt.title('Plot b/w happiness score and Generosity',fontsize=15)
plt.show()

# %% [markdown]
# Sub Saharan africa countries are the less happy with happiness score below 5 and have less generosity with range from 0.5 to 5 only  compared to others.

# %% [markdown]
# # Correlation

# %%
df.corr()
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Standard Error                       0.158516        -0.177254
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                              -0.733644         0.740605
# Health (Life Expectancy)            -0.735613         0.724200
# Freedom                             -0.556886         0.568211
# Trust (Government Corruption)       -0.372315         0.395199
# Generosity                          -0.160142         0.180319
# Dystopia Residual                   -0.521999         0.530474
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                       0.158516                 -0.785267
# Happiness Score                     -0.177254                  0.780966
# ...

# %%
#checking the correlation of happiness score with every other column
df.corr()['Happiness Score'].sort_values()
# Out:
# Happiness Rank                  -0.992105
# Standard Error                  -0.177254
# Generosity                       0.180319
# Trust (Government Corruption)    0.395199
# Dystopia Residual                0.530474
# Freedom                          0.568211
# Health (Life Expectancy)         0.724200
# Family                           0.740605
# Economy (GDP per Capita)         0.780966
# Happiness Score                  1.000000
# Name: Happiness Score, dtype: float64

# %%
#correlation using heatmap
sns.heatmap(df.corr(),annot=True,linewidth='0.5',linecolor='white',fmt='.2f')
plt.show()

# %% [markdown]
# #observations from the correlation heatmap

# %% [markdown]
# 1. some columns have postive correlation and some columns have negative correlation with the target column(Happiness score).
# 2. Economy(GDP per capita), Family and Health(Life expectancy) have the highest correlation of 78% , 74% ,72% respectively with the target column(Happiness score) which are very good bonds.
# 3. Freedom, Trust(Government corruption) and Dystopia residual have moderate correlation of 57% , 40% , 53% respectively with Happiness score.
# 4. Generosity have only 18% of correlation with Happiness score.
# 5. Standard error have negative correlation.
# 6. Happiness rank number have highly negative correaltion with Happiness score.

# %% [markdown]
# # Describing dataset:

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
#df.describe() vizualizing using heat map
describe_df = round(df.describe()[1:].transpose(),2)
sns.heatmap(describe_df,annot = True, fmt = 'f',linewidth = 2)
plt.title('Variation summary')
plt.xticks(fontsize=12)
plt.yticks(fontsize=10)
plt.show()

# %% [markdown]
# #observations from the describe of datasets

# %% [markdown]
# ->All the columns have 158 rows with no null values

# %% [markdown]
# ->Happiness score
# 1. mean = 5.3757
# 2. std = 1.1450
# 3. min_value = 2.8390
# 4. max_value = 7.5870

# %% [markdown]
# ->standard error
# 1. mean = 0.047
# 2. std = 0.017
# 3. min_value = 0.0184
# 4. max_value = 0.1369

# %% [markdown]
# -> Economy (GDP per Capita)
# 1. mean = 0.8461
# 2. std = 0.4031
# 3. min_value = 0
# 4. max_value = 1.6904

# %% [markdown]
# -> Family
# 1. mean = 0.9910
# 2. std = 0.2723
# 3. min_value = 0
# 4. max_value = 1.4022

# %% [markdown]
# -> Health (Life Expectancy)
# 1. mean = 0.630259
# 2. std = 0.247078
# 3. min_value = 0
# 4. max_value = 1.025250

# %% [markdown]
# -> Freedom
# 1. mean = 0.428615
# 2. std = 0.150693
# 3. min_value = 0
# 4. max_value = 0.669730

# %% [markdown]
# -> Trust (Government Corruption)
# 1. mean = 0.143422
# 2. std = 0.120034
# 3. min_value = 0
# 4. max_value = 0.551910

# %% [markdown]
# -> Generosity
# 1. mean = 0.237296
# 2. std = 0.126685
# 3. min_value = 0
# 4. max_value = 0.795880

# %% [markdown]
# -> Dystopia Residual
# 1. mean = 2.098977
# 2. std = 0.553550
# 3. min_value = 0.328580
# 4. max_value = 3.602140

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %% [markdown]
# From the above we can have columns , total  non null count, datatypes of each column, memeory used by the dataframe

# %% [markdown]
# # checking outliers

# %%
colno=df.columns[3:].values
for i in range(0, len(colno)):
    plt.subplot(3,5,i+1)
    sns.boxplot(df[colno[i]])
    plt.tight_layout()

# %% [markdown]
# From the above ouput we can see that columns['Happiness Score','Economy(GDP per Capita)', 'Health(Life Expectancy)', 'Freedom'] have no outliers and columns = ['Family', 'Generosity','Dystopia Residual'] have less outliers and columns=['Standard error', 'Trust(Government Corruption)'] has more outliers.

# %% [markdown]
# # Skewness:

# %%
df.skew()
# Out:
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
#vizualizing the skewness
for i in range(0, len(colno)):
    
    sns.displot(df[colno[i]],kde=True)
    plt.show()

# %% [markdown]
# From the above outcome we can see almost every columns has skewness

# %% [markdown]
# # Data preprocessing

# %% [markdown]
# # Data cleaning:

# %%
#checking correlation between target column(Happiness Rank) and other columns
df.corr()['Happiness Score']
# Out:
# Happiness Rank                  -0.992105
# Happiness Score                  1.000000
# Standard Error                  -0.177254
# Economy (GDP per Capita)         0.780966
# Family                           0.740605
# Health (Life Expectancy)         0.724200
# Freedom                          0.568211
# Trust (Government Corruption)    0.395199
# Generosity                       0.180319
# Dystopia Residual                0.530474
# Name: Happiness Score, dtype: float64

# %%
# droping the colmns which has more outliers
df1= df.drop(['Standard Error','Trust (Government Corruption)'], axis =1)

# %%
df1
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Economy (GDP per Capita)   Family  \
# 0              7.587                   1.39651  1.34951
# 1              7.561                   1.30232  1.40223
# ...

# %% [markdown]
# # Removing outliers:

# %% [markdown]
# using Zscore technique

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(df1.iloc[:,3:]))
z.shape
# Out:
# (158, 7)

# %%
threshold = 3   # rule of thumb
#index number
print(np.where(z>3))
# Out:
# (array([128, 147, 155, 157], dtype=int64), array([5, 2, 6, 2], dtype=int64))

# %%
len(np.where(z>3)[0])
# Out:
# 4

# %%
df_new=df1[(z<3).all(axis=1)]
print('old dataframe',df1.shape)
print('new dataframe',df_new.shape)
print('no of rows dropped',df1.shape[0]-df_new.shape[0])
# Out:
# old dataframe (158, 10)
# new dataframe (154, 10)
# no of rows dropped 4

# %% [markdown]
# # percentage data loss:

# %%
loss_percentage = (158-154)/158*100
print(loss_percentage,'%')
# Out:
# 2.5316455696202533 %

# %% [markdown]
# # Transforming data to remove skewness

# %%
df_new
# Out:
#           Country              Region  Happiness Rank  Happiness Score  \
# 0     Switzerland      Western Europe               1            7.587
# 1         Iceland      Western Europe               2            7.561
# 2         Denmark      Western Europe               3            7.527
# 3          Norway      Western Europe               4            7.522
# 4          Canada       North America               5            7.427
# ..            ...                 ...             ...              ...
# 151  Burkina Faso  Sub-Saharan Africa             152            3.587
# 152   Afghanistan       Southern Asia             153            3.575
# 153        Rwanda  Sub-Saharan Africa             154            3.465
# 154         Benin  Sub-Saharan Africa             155            3.340
# 156       Burundi  Sub-Saharan Africa             157            2.905
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
#independent column
x=df_new.iloc[:,4:]
#dependent column or target column
y=df_new.iloc[:,3]

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')

# %%
#checking skewness after removing skewness
pd.DataFrame(x).skew()
# Out:
# 0   -0.127122
# 1   -0.145684
# 2   -0.183012
# 3   -0.082911
# 4    0.020962
# 5    0.015412
# dtype: float64

# %% [markdown]
# # since our target column is continous data we will use LinerRegression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.model_selection import train_test_split

# %%
#splitting the data to train and to test
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=20,random_state=42)

# %%
#shape of data to be trained
x_train.shape
# Out:
# (134, 6)

# %%
#shape of data to be trained 
y_train.shape
# Out:
# (134,)

# %%
#shape of data which is tested 
x_test.shape
# Out:
# (20, 6)

# %%
#shape of actual output
y_test.shape
# Out:
# (20,)

# %%
#creating instance for linearRegression
lm=LinearRegression()

# %%
#training the Model
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#checking coeffient
lm.coef_
# Out:
# array([0.42530766, 0.22738709, 0.23348047, 0.19964931, 0.10581236,
#        0.51982251])

# %%
#checking intercept
lm.intercept_
# Out:
# 5.431493846474891

# %%
#score of trained data
lm.score(x_train,y_train)
# Out:
# 0.9904127872112927

# %%
#predicting  the target value
y_pred=lm.predict(x_test)

# %%
print("predict happiness score:",y_pred)
print("actual happiness score:",y_test)
# Out:
# predict happiness score: [6.92694388 4.9655851  3.61949035 4.69303732 4.75519738 5.7559968
#  7.00580822 6.09084067 6.38451658 5.86174155 5.17930992 3.88254878
#  6.80481146 3.81329751 5.10768321 5.0220741  4.64001443 7.32516604
#  7.24845854 4.57053053]
# actual happiness score: 15     6.983
# 94     4.959
# 154    3.340
# 105    4.786
# 109    4.686
# 65     5.695
# 18     6.937
# 45     5.987
# 36     6.302
# 55     5.833
# 85     5.124
# 143    3.845
# 19     6.901
# 149    3.656
# 86     5.123
# 93     4.971
# 119    4.517
# 12     7.200
# 9      7.284
# 114    4.610
# Name: Happiness Score, dtype: float64

# %%
print('error: ')
print('mean absolue error: ',mean_absolute_error(y_test,y_pred))
print('mean squared error: ',mean_squared_error(y_test,y_pred))

#calculating the error
print('\nroot mean squared error: ',np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# error:
# mean absolue error:  0.07925612450475447
# mean squared error:  0.009826555194167131
#
# root mean squared error:  0.09912898261440561

# %% [markdown]
# # Conclusion:

# %% [markdown]
# From the above outcome we can see that our model has almost 0 root mean squared error i.e. our model is working almost 100 percent.

# %%
from sklearn.metrics import r2_score

# %%
#calculating r2_score 
#it is the change in y whenever x is being changed
r2_score(y_test,y_pred)
# Out:
# 0.9929410138427154
