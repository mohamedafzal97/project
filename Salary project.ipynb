# %% [markdown]
# # Salary Project

# %%
#importing all the required libraries for EDA and vizualiztion.
import pandas as pd    # library for EDA.
import numpy as np     # library for numerical calculations.
import seaborn as sns  # library for vizualization.
import matplotlib.pyplot as plt  # library for vizualization.
import warnings
warnings.filterwarnings('ignore')  # to ignore warnings

# %%
#loading the data set
df = pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset3/main/Salaries.csv')
df
# Out:
#          rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0        Prof          B             19           18  Male  139750
# 1        Prof          B             20           16  Male  173200
# 2    AsstProf          B              4            3  Male   79750
# 3        Prof          B             45           39  Male  115000
# 4        Prof          B             40           41  Male  141500
# ..        ...        ...            ...          ...   ...     ...
# 392      Prof          A             33           30  Male  103106
# 393      Prof          A             31           19  Male  150564
# 394      Prof          A             42           25  Male  101738
# 395      Prof          A             25           15  Male   95329
# 396  AsstProf          A              8            4  Male   81035
#
# [397 rows x 6 columns]

# %%
#checking the type of dataset
type(df)
#since the dataset is already dataframe so, no need to again create dataframe.
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Performing EDA

# %%
# checking if there are any null values and summing up
df.isnull().sum()
# Out:
# rank             0
# discipline       0
# yrs.since.phd    0
# yrs.service      0
# sex              0
# salary           0
# dtype: int64

# %%
#isnull using heatmap
plt.rcParams['figure.facecolor']='pink'
sns.heatmap(df.isnull())
plt.show()

# %% [markdown]
# In the above we can see that there are no null values our heatmap is clean for al the columns.

# %%
#printing the columns of dataframe
df.columns
# Out:
# Index(['rank', 'discipline', 'yrs.since.phd', 'yrs.service', 'sex', 'salary'], dtype='object')

# %% [markdown]
# #observations
# 1. dataframe has 397 rows and 6 columns
# 2. there are no null values present in the dataframe

# %%
plt.rcParams['figure.facecolor']='pink'
sns.countplot(df['sex'])
plt.show()

# %% [markdown]
# In the above we can see that about 360 rows belongs to male and about 37 rows belongs to female sex.

# %%
#scatterplot b/w years of service and salary to see distribution of data
plt.rcParams['figure.figsize']=(15,7)
sns.scatterplot(x=df['yrs.service'],y=df['salary'],markers =True,hue=df['rank'],s=150)
plt.title('plot b/w years of experience and salary',fontsize=15)
plt.legend(loc='best',fontsize=15)
plt.show()

# %% [markdown]
# # In the above outcome we can see that:
# 1. Majority of Assistant professors have less years of service of range 0 to 7 years and majority of them have low salary of range 50000 to 100000 compared to others
# 2. Majority of Associate professors have years of service between 5 to 25 with salary range from 60000 to 12500.
# 3. Professors are distributed from 0 to above 50 years of service with salary range from 50000 to 225000 and above.

# %%
#scatterplot b/w rank and salary to see distribution of data
sns.scatterplot(x=df['rank'],y=df['salary'],markers =True,hue=df['sex'],s=150)
plt.rcParams['figure.figsize']=(15,7)
plt.title('plot b/w rank and salary',fontsize=15)
plt.legend(loc='best',fontsize=15)
plt.show()

# %% [markdown]
# 1. From the above outcome we can see that we have more professors and they have the highest salary compared to assocciate professor and assistant professor.
# 2. we have only males in  the professor rank and mix in other two ranks.

# %%
#scatterplot b/w  and salary to see distribution of data
sns.scatterplot(x=df['discipline'],y=df['salary'],markers =True,hue=df['rank'],s=150)
plt.rcParams['figure.figsize']=(15,7)
plt.title('plot b/w rank and salary',fontsize=15)
plt.legend(loc='best',fontsize=15)
plt.show()

# %% [markdown]
# In the above outcome we can see that we have the highest salary for 'B' discipline for professor rank.

# %%
#scatterplot b/w sex and salary to see distribution of data
sns.scatterplot(x=df['sex'],y=df['salary'],markers =True,hue=df['rank'],s=150)
plt.rcParams['figure.figsize']=(15,7)
plt.title('plot b/w sex and salary',fontsize=15)
plt.legend(loc='best',fontsize=15)
plt.show()

# %% [markdown]
# In the above outcome we can see that male have the highest salary of above 225000 for professor rank compared to female.

# %% [markdown]
# # correlation:

# %%
df.corr()
# Out:
#                yrs.since.phd  yrs.service    salary
# yrs.since.phd       1.000000     0.909649  0.419231
# yrs.service         0.909649     1.000000  0.334745
# salary              0.419231     0.334745  1.000000

# %%
#checking the correaltion of taget column(salary) with every other column.
df.corr()['salary'].sort_values()
# Out:
# yrs.service      0.334745
# yrs.since.phd    0.419231
# salary           1.000000
# Name: salary, dtype: float64

# %%
#correaltion using heatmap
sns.heatmap(df.corr(),annot=True,linewidth='0.5',linecolor='black',fmt='f')
plt.show()

# %% [markdown]
# #obseravtion from heatmap
# 1. All the columns have positive correaltion with target column(salary).
# 2. yrs.since.phd column have the highest correaltion of 41 percent with the target column(salary) which is a good bond compared to yrs.service column.
# 3. yrs.service column have 33 percent of correlation with salary column.

# %% [markdown]
# # Describing dataset:

# %%
df.describe().transpose()
# Out:
#                count           mean           std      min      25%       50%  \
# yrs.since.phd  397.0      22.314861     12.887003      1.0     12.0      21.0
# yrs.service    397.0      17.614610     13.006024      0.0      7.0      16.0
# salary         397.0  113706.458438  30289.038695  57800.0  91000.0  107300.0
#
#                     75%       max
# yrs.since.phd      32.0      56.0
# yrs.service        27.0      60.0
# salary         134185.0  231545.0

# %%
#df.decribe() using heatmap
sns.heatmap(df.describe().transpose(), annot = True,linewidth='0.5',linecolor='white',fmt='f')
plt.show()

# %% [markdown]
# #observations from the describe of dataset

# %% [markdown]
# All the columns have 397 rows

# %% [markdown]
# salary
# 1. mean = 113706.458438
# 2. std = 30289.038695
# 3. min salary = 57800.0
# 4. max salary = 231545.0

# %% [markdown]
# yrs.since.phd
# 1. mean = 22.314861
# 2. std = 12.887003
# 3. min value = 1.0
# 4. max value = 56.0

# %% [markdown]
# yrs.service
# 1. mean = 17.614610
# 2. std = 13.006024
# 3. min value = 0
# 4. max value = 60.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   rank           397 non-null    object
#  1   discipline     397 non-null    object
#  2   yrs.since.phd  397 non-null    int64
#  3   yrs.service    397 non-null    int64
#  4   sex            397 non-null    object
#  5   salary         397 non-null    int64
# dtypes: int64(3), object(3)
# memory usage: 18.7+ KB

# %% [markdown]
# From the above we can have columns , total  non null count, datatypes of each column, memeory used by the dataframe

# %% [markdown]
# # Data preprocessing

# %% [markdown]
# # Data cleaning:

# %%
#dropig the unwanted columns
df1=df.drop(['rank','discipline','sex'],axis=1)
df1.head()
# Out:
#    yrs.since.phd  yrs.service  salary
# 0             19           18  139750
# 1             20           16  173200
# 2              4            3   79750
# 3             45           39  115000
# 4             40           41  141500

# %% [markdown]
# # checking outliers:

# %%
lis=df1.columns.values
for i in range(0, len(lis)):
    plt.subplot(3,5,i+1)
    sns.boxplot(df[lis[i]])
    plt.tight_layout()

# %% [markdown]
# From the above outcome we can see that yrs.since.phd have no outliers and other two columns have very less outliers.

# %% [markdown]
# # reamoving outliers:

# %% [markdown]
# using Zscore technique

# %%
from scipy.stats import zscore
z=np.abs(zscore(df1))
z.shape
# Out:
# (397, 3)

# %%
threshold = 3   # rule of thumb
#index number
print(np.where(z>3))
# Out:
# (array([ 43, 131, 330, 364], dtype=int64), array([2, 1, 1, 2], dtype=int64))

# %%
len(np.where(z>3)[0])
# Out:
# 4

# %%
df_new=df1[(z<3).all(axis=1)]
print('old dataframe',df1.shape)
print('new dataframe',df_new.shape)
print('no of rows dropped',df1.shape[0]-df_new.shape[0])
# Out:
# old dataframe (397, 3)
# new dataframe (393, 3)
# no of rows dropped 4

# %% [markdown]
# # percentage data lose:

# %%
loss_percentage = (397-393)/397*100
print(loss_percentage,'%')
# Out:
# 1.0075566750629723 %

# %% [markdown]
# # checking skewness:

# %%
df1.skew()
# Out:
# yrs.since.phd    0.300880
# yrs.service      0.650569
# salary           0.714568
# dtype: float64

# %%
lis=df1.columns.values
for i in range(0, len(lis)):
    sns.displot(df1[lis[i]],kde=True)
    plt.tight_layout()

# %% [markdown]
#  From aboveoutcome we can see that there is little amount of skewness in every column.

# %% [markdown]
# # Transforming data to remove skewness

# %%
#independent column
x=df1.iloc[:,:-1].values
#dependent column or target column
y=df1.iloc[:,-1].values

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')

# %%
#checking skewness after removing skewness
pd.DataFrame(x).skew()
# Out:
# 0   -0.132757
# 1   -0.122152
# dtype: float64

# %%
#scaling independent data using StandardScaler
#mean=0, std=1
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
x_scaled=scaler.fit_transform(x)

# %% [markdown]
# # splitting data into train and test

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.20,random_state=32)

# %%
#checking the shape
x_train.shape, y_train.shape, x_test.shape , y_test.shape
# Out:
# ((317, 2), (317,), (80, 2), (80,))

# %% [markdown]
# # Since our target column is continous data we will use RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
#creating instance for RandomForestRegressor
RFR = RandomForestRegressor(n_estimators = 150, random_state = 32)

# %%
# training model using training data
RFR.fit(x_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=150, random_state=32)

# %%
#predicting the data
y_pred=RFR.predict(x_test)

# %% [markdown]
# # Evaluating:

# %%
#dataframe of actual data and predicted data
diff=y_test-y_pred
data={'Actual':y_test,'Predicted':y_pred,'Difference':diff}
pd.DataFrame(data)
# Out:
#     Actual      Predicted    Difference
# 0    71065  110553.728889 -39488.728889
# 1    92000   91941.197463     58.802537
# 2    88650   92250.631000  -3600.631000
# 3    77202   83987.906667  -6785.906667
# 4   165000  116253.926667  48746.073333
# ..     ...            ...           ...
# 75  153303  120459.800000  32843.200000
# 76   95611  126170.021111 -30559.021111
# 77  112696  142550.067778 -29854.067778
# 78  126933  118531.191222   8401.808778
# 79  108200  109763.375016  -1563.375016
#
# [80 rows x 3 columns]

# %%
# calculating the mean absolute error
abserror= abs(y_pred - y_test)
print('mean absolute error:', np.mean(abserror))
# Out:
# mean absolute error: 18241.07425659433

# %%
#calculating the percentage of mean absolute rror
mean_abs_percentage_error= 100 * (abserror / y_test)
print('mean absolute percentage error:', round(np.mean(mean_abs_percentage_error),2),'%')
# Out:
# mean absolute percentage error: 14.88 %

# %%
#calculation accuracy of model
accuracy = 100 - np.mean(mean_abs_percentage_error)
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Accuracy: 85.12 %.

# %% [markdown]
# # conclusion:

# %% [markdown]
# In the above outcome you can see that our model has 14.88 percent of error and our model is working 85.12 percent
